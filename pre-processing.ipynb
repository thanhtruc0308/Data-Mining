# %%
import pandas as pd
import numpy as np

full_df = pd.read_csv("./dataset/data.csv", encoding = "unicode_escape")
full_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
missing_data = pd.DataFrame(full_df.isnull().sum(), columns=["Count"])
missing_data.sort_values(by=["Count"])
# Out:
#               Count
# InvoiceNo         0
# StockCode         0
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# Country           0
# Description    1454
# CustomerID   135080

# %%
full_df[full_df.CustomerID.isnull()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 622     12/1/2010 11:52       0.00         NaN  United Kingdom
# ...

# %%
full_df[full_df.Description.isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12/1/2010 11:52        0.0
# 1970      536545     21134         NaN         1  12/1/2010 14:32        0.0
# 1971      536546     22145         NaN         1  12/1/2010 14:33        0.0
# 1972      536547     37509         NaN         1  12/1/2010 14:33        0.0
# 1987      536549    85226A         NaN         1  12/1/2010 14:34        0.0
# ...          ...       ...         ...       ...              ...        ...
# 535322    581199     84581         NaN        -2  12/7/2011 18:26        0.0
# 535326    581203     23406         NaN        15  12/7/2011 18:31        0.0
# 535332    581209     21620         NaN         6  12/7/2011 18:35        0.0
# 536981    581234     72817         NaN        27  12/8/2011 10:33        0.0
# 538554    581408     85175         NaN        20  12/8/2011 14:06        0.0
#
#         CustomerID         Country
# ...

# %%
full_df["CustomerID"] = full_df["CustomerID"].fillna(99999)
full_df["CustomerID"] = full_df["CustomerID"].apply(lambda x: str(x)[:-2])
full_df["CustomerID"]
# Out:
# 0         17850
# 1         17850
# 2         17850
# 3         17850
# 4         17850
#           ...
# 541904    12680
# 541905    12680
# 541906    12680
# 541907    12680
# 541908    12680
# Name: CustomerID, Length: 541909, dtype: object

# %%
full_df[full_df["UnitPrice"]==0]
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 622       536414     22139                           NaN        56
# 1970      536545     21134                           NaN         1
# 1971      536546     22145                           NaN         1
# 1972      536547     37509                           NaN         1
# 1987      536549    85226A                           NaN         1
# ...          ...       ...                           ...       ...
# 536981    581234     72817                           NaN        27
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538554    581408     85175                           NaN        20
# 538919    581422     23169                       smashed      -235
#
#             InvoiceDate  UnitPrice CustomerID         Country
# 622     12/1/2010 11:52        0.0      99999  United Kingdom
# ...

# %%
full_df.drop(full_df[full_df["UnitPrice"]==0].index, inplace=True)

# %%
all_stock = list(set(full_df['StockCode']))
all_stock.sort()

# %%
basket = full_df.groupby(['InvoiceNo','CustomerID'], as_index= False).agg({'StockCode': lambda s: list(set(s))}) # grouping product from the same invoice. 
basket
# Out:
#       InvoiceNo CustomerID                                          StockCode
# 0        536365      17850  [84029E, 84406B, 22752, 85123A, 84029G, 71053,...
# 1        536366      17850                                     [22632, 22633]
# 2        536367      13047  [22745, 22622, 84969, 21754, 22748, 22310, 226...
# 3        536368      13047                       [22914, 22960, 22913, 22912]
# 4        536369      13047                                            [21756]
# ...         ...        ...                                                ...
# 23793   C581484      16446                                            [23843]
# 23794   C581490      14397                                     [23144, 22178]
# 23795   C581499      15498                                                [M]
# 23796   C581568      15311                                            [21258]
# 23797   C581569      17315                                     [84978, 20979]
#
# [23798 rows x 3 columns]

# %%
for item in all_stock:
    basket[item] = item
basket
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_13924/993611400.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   basket[item] = item
#       InvoiceNo CustomerID                                          StockCode  \
# 0        536365      17850  [84029E, 84406B, 22752, 85123A, 84029G, 71053,...
# 1        536366      17850                                     [22632, 22633]
# 2        536367      13047  [22745, 22622, 84969, 21754, 22748, 22310, 226...
# 3        536368      13047                       [22914, 22960, 22913, 22912]
# 4        536369      13047                                            [21756]
# ...         ...        ...                                                ...
# ...

# %%
def binarySearch(arr, l, r, x):
    x = str(x)
    if (r >= l):         
        mid = int(l + (r - l) / 2)

        if (str(arr[mid]) == x): 
            arr[mid] = 'True'
        if (mid > l and str(arr[mid - 1]) == x):
            arr[mid-1] = 'True'
        if (mid < r and str(arr[mid + 1]) == x):
            arr[mid+1] = 'True'

        if (str(arr[mid]) > x):
            return binarySearch(arr, l, mid - 2, x)
         
        return binarySearch(arr, mid + 2, r, x)

    return arr

# %%
data = np.array(basket)

# %%
for row in range(len(data)):
    for item in data[row][2]:
        binarySearch(data[row],3,len(all_stock) - 1,item)

# %%
for row in range(len(data)):
    for col in range(3,len(all_stock)):
        if data[row][col] != 'True':
            data[row][col] = 'False'

# %%
data = pd.DataFrame(data,columns=basket.columns)
data = data.drop(columns=['StockCode','gift_0001_10','gift_0001_20','gift_0001_30','gift_0001_40','gift_0001_50'],axis=1)
data
# Out:
#       InvoiceNo CustomerID  10002  10080  10120 10123C 10124A 10124G  10125  \
# 0        536365      17850  False  False  False  False  False  False  False
# 1        536366      17850  False  False  False  False  False  False  False
# 2        536367      13047  False  False  False  False  False  False  False
# 3        536368      13047  False  False  False  False  False  False  False
# 4        536369      13047  False  False  False  False  False  False  False
# ...         ...        ...    ...    ...    ...    ...    ...    ...    ...
# 23793   C581484      16446  False  False  False  False  False  False  False
# 23794   C581490      14397  False  False  False  False  False  False  False
# 23795   C581499      15498  False  False  False  False  False  False  False
# 23796   C581568      15311  False  False  False  False  False  False  False
# 23797   C581569      17315  False  False  False  False  False  False  False
#
# ...

# %%
data.to_csv('Preprocess.csv', index=False)
